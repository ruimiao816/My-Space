# %% [markdown]
# # Lab 4. My first data science project

# %% [markdown]
# ## In this lab you will apply the concepts and techniques developed in sessions 1-6. You are expected to work on the assignments on your own between Tuesday the 8th at 11am and Wednesday the 9th at 11 am. We recomend hadning in an hour early to aviod any issues with traffic on the ELE.
#
# ## You are expected to submit the code developed as well as a brief description of your findings and insights for each assigment.
#
# ## You can do this by creating [markdown cells](https://www.tutorialspoint.com/jupyter/jupyter_notebook_markdown_cells.htm#:~:text=%20Jupyter%20Notebook%20-%20Markdown%20Cells%20%201,To%20attach%20link%20to%20text%2C%20place...%20More%20) in jupyter notebook, and writting in them.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
### Let's load the gapminder dataset
gapminder = pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458/master/data/gapminder.tsv', sep='\t')

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %% [markdown]
# ### (1) Use pairplot to visualise the data. Colour code data points by the continent they are from.

# %%
fig = sns.pairplot(gapminder, hue='continent')

# %% [markdown]
# ### (2) What patterns can you see? Are there any outliars?

# %% [markdown]
# For lifeExp-year chart, the tendency for the average life expectancy to become larger as the year progresses. There are three outliers in the diagram, two green for Africa and one blue for Asia.

# %% [markdown]
# For pop-year chart, population growth over time. Some countries in Africa, Oceania, Europe and Asia have small initial populations and are growing more slowly. The Americas have medium initial populations and moderate growth rates. Two countries in Asia have large initial populations and are growing rapidly.

# %% [markdown]
# For gdpPercap-year chart, the general trend is for GDP per capita to increase over time. Africa's initial GDP per capita is low and grows very slowly almost in a straight line. In the Americas there are 2 types of line, one with a small initial value and a slow growth rate and the other with a high initial value and a fast growth rate. Europe has a medium initial value and grows faster. The outliers are certain data for Asia, where the initial GPD per capita is particularly high over 100,000 and decreases rapidly over time.

# %% [markdown]
# For lifeExp-pop chart, most of the points are clustered together, and life expectancy ranges from 30-80 for the same number of people. Outliers have one point and a group of points, a green one representing Africa with a life expectancy of around 10 years. A group of blue dots represents Asia, which has a significantly larger population.

# %% [markdown]
# For gdpPercap-pop chart，most of the points are clustered together, with two groups of blue representing Asian outliers. One group has a low population size and an exceptionally high GDP. The other group is particularly large in population but very low in GDP.

# %% [markdown]
# For lifeExp-gdpPercap chart, most points are clustered together, with GPD per capita distributed from 0-50,000 and life expectancy from 30 to 80+. Outliers are a point and a group of points. A green point representing Africa has a life expectancy of around 10 and a very low GPD per capita. A group of blue dots represents Asia with life expectancy of 60-70 years and a GPD per capita of 50,000+.

# %% [markdown]
# ### (3) Filter the dataset to find rows in which life GDP per capita is greater than 60,000

# %%
gdpPercapFilter=gapminder['gdpPercap']>60000

# %%
gapminder[gdpPercapFilter]
# Out:
#     country continent  year  lifeExp     pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565  160000  108382.35290
# 853  Kuwait      Asia  1957   58.033  212846  113523.13290
# 854  Kuwait      Asia  1962   60.470  358266   95458.11176
# 855  Kuwait      Asia  1967   64.624  575003   80894.88326
# 856  Kuwait      Asia  1972   67.712  841934  109347.86700

# %% [markdown]
# ### (4) What does this tell us about the data, as seen in the question (1)  pairplot?

# %% [markdown]
# By filtering the data for GDP per capita above 60,000, the outliers in the first question, we can see that they all come from the same country, Kuwait, in Asia. We can next analyse this for the country of Kuwait.

# %% [markdown]
# ### (5) Find the rows in the dataframe with the top 20 life expectancies

# %%
gapminder.iloc[0:20]
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# ...

# %% [markdown]
# ### (6) Plot the evolution of life expectancy, population and GDP per capita of Kuwait

# %%
KuwaitFilter=gapminder['country']=='Kuwait'

# %%
gapminder[KuwaitFilter]
# Out:
#     country continent  year  lifeExp      pop     gdpPercap
# 852  Kuwait      Asia  1952   55.565   160000  108382.35290
# 853  Kuwait      Asia  1957   58.033   212846  113523.13290
# 854  Kuwait      Asia  1962   60.470   358266   95458.11176
# 855  Kuwait      Asia  1967   64.624   575003   80894.88326
# 856  Kuwait      Asia  1972   67.712   841934  109347.86700
# 857  Kuwait      Asia  1977   69.343  1140357   59265.47714
# 858  Kuwait      Asia  1982   71.309  1497494   31354.03573
# 859  Kuwait      Asia  1987   74.174  1891487   28118.42998
# 860  Kuwait      Asia  1992   75.190  1418095   34932.91959
# 861  Kuwait      Asia  1997   76.156  1765345   40300.61996
# 862  Kuwait      Asia  2002   76.904  2111561   35110.10566
# 863  Kuwait      Asia  2007   77.588  2505559   47306.98978

# %%
popK = gapminder[KuwaitFilter]['pop'].values.tolist()
lifeExpK = gapminder[KuwaitFilter]['lifeExp'].values.tolist()
gdpPercapK = gapminder[KuwaitFilter]['gdpPercap'].values.tolist()

# %%
ax=sns.scatterplot(x=popK, y=lifeExpK)
ax.set_title('The relationship between life expectancy and population in Kuwait');
ax.set_xlabel('popK');
ax.set_ylabel('lifeExpK');

# %%
ax=sns.scatterplot(x=gdpPercapK, y=lifeExpK)
ax.set_title('The relationship between life expectancy and gdpPercap in Kuwait');
ax.set_xlabel('gdpPercapK');
ax.set_ylabel('lifeExpK');

# %%
ax=sns.scatterplot(x=popK, y=gdpPercapK)
ax.set_title('The relationship between pop and gdpPercap in Kuwait');
ax.set_xlabel('popK');
ax.set_ylabel('gdpPercapK');

# %%
x = sns.regplot(x='gdpPercap', y='lifeExp', data=gapminder[KuwaitFilter])

# %%
x1 = sns.regplot(x='pop', y='lifeExp', data=gapminder[KuwaitFilter])

# %%
x3 = sns.regplot(x='pop', y='gdpPercap', data=gapminder[KuwaitFilter])

# %%
ax = sns.kdeplot(x=gapminder[KuwaitFilter]['gdpPercap'],y=gapminder[KuwaitFilter]['lifeExp'],shade=True)

# %%
ax = sns.kdeplot(x=gapminder[KuwaitFilter]['pop'],y=gapminder[KuwaitFilter]['lifeExp'],shade=True)

# %%
ax = sns.kdeplot(x=gapminder[KuwaitFilter]['pop'],y=gapminder[KuwaitFilter]['gdpPercap'],shade=True)

# %%
gapminder[KuwaitFilter].plot(x='year',y='lifeExp')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
gapminder[KuwaitFilter].plot(x='year',y='gdpPercap')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
gapminder[KuwaitFilter].plot(x='year',y='pop')
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ### (7) Visualise the distribution of GDP per capita of countries and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# #### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# #### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
x = sns.regplot(x='gdpPercap', y='lifeExp', data=gapminder)

# %%
x = sns.lmplot(x='gdpPercap', y='lifeExp', hue='country', data=gapminder)

# %%
gapminder['pop (million)']=gapminder['pop']/1000000

# %%
plt.scatter('year', 'lifeExp',
             s='pop (million)',
             alpha=0.5, data=gapminder)
plt.xlabel("year", size=16)
plt.ylabel("lifeExp", size=16)
plt.title("the distribution of GDP per capita of countries and life expectancy", size=18)
# Out:
# Text(0.5, 1.0, 'the distribution of GDP per capita of countries and life expectancy')

# %% [markdown]
# The lmpot is a linear regression with data for each country separately, with different colours for different countries. From the graph we can see that for most countries, life expectancy increases as GDP per capita increases, while for Kuwait it is the exact opposite, with life expectancy becoming shorter as GDP per capita increases.
# The regplot is a linear regression combining data from all countries and the line shows that life expectancy increases as GDP per capita increases.

# %% [markdown]
# ### (8) Visualise the distribution of year and life expectancy across the dataframe. Use a second graph that includes a linear regression of those variables.

# %% [markdown]
# ### Tip: have a look at seaborn-based techniques to represent relationships between two variables.
# ### check the following link for alternatives: https://seaborn.pydata.org/tutorial.html

# %%
x = sns.regplot(x='year', y='lifeExp', data=gapminder)

# %%
x = sns.lmplot(x='year', y='lifeExp', hue='country', data=gapminder)

# %% [markdown]
# The lmpot is a linear regression with separate data for each country, with different colours for different countries. From the graph we can see that for most countries life expectancy increases with the number of years, while for a few countries the opposite is true, life expectancy becomes shorter as the number of years increases.
# The regplot is a linear regression combining data from all countries and the straight line shows that life expectancy increases with year.

# %% [markdown]
# ### (9) Use Boxplots or violinplots to visualise the distribution of change in life expectancy from 1952 to 2007.
#
# Hint tools from lab 6 may be helpful.

# %%
ax = sns.boxplot(x='year', y='lifeExp', data=gapminder)
ax.set_title('Boxplot of life expectancy by year')
ax.set_xlabel('year')
ax.set_ylabel('life expectancy')
# Out:
# Text(0, 0.5, 'life expectancy')

# %% [markdown]
# ### (10) Continue this analysis of the data. Include code cells, their outputs and markdown cells where you write about your findings. What patterns can you observe in the data?

# %%
#First analysis
gapminder['GDP (million)']=gapminder['gdpPercap']*gapminder['pop']/1000000

# %%
gapminder
# Out:
#           country continent  year  lifeExp       pop   gdpPercap  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
#                GDP  GDP million  GDP (million)
# 0     6.567086e+09  6567.086330    6567.086330
# 1     7.585449e+09  7585.448670    7585.448670
# ...

# %%
sns.lineplot(x="year", y="GDP (million)",
             hue="continent", data=gapminder)
#GPD=population*GPD per capita, plotting the change in GDP over the years for different continents
# Out:
# <AxesSubplot:xlabel='year', ylabel='GDP (million)'>

# %%
#Second analysis
AsiaData=gapminder[gapminder['continent']=='Asia']

# %%
AsiaData
# Out:
#           country continent  year  lifeExp       pop    gdpPercap  \
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# ...           ...       ...   ...      ...       ...          ...
# 1675  Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538
# 1676  Yemen, Rep.      Asia  1992   55.599  13367997  1879.496673
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257  2234.820827
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906
#
#                GDP   GDP million  GDP (million)
# 0     6.567086e+09   6567.086330    6567.086330
# 1     7.585449e+09   7585.448670    7585.448670
# ...

# %%
average_AsiaPop=AsiaData.groupby('country')['pop'].mean()

# %%
average_AsiaPop
# Out:
# country
# Afghanistan           1.582372e+07
# Bahrain               3.739132e+05
# Bangladesh            9.075540e+07
# Cambodia              8.510431e+06
# China                 9.581601e+08
# Hong Kong, China      4.792259e+06
# India                 7.011307e+08
# Indonesia             1.483228e+08
# Iran                  4.230171e+07
# Iraq                  1.418750e+07
# Israel                3.845611e+06
# Japan                 1.117588e+08
# Jordan                2.667973e+06
# Korea, Dem. Rep.      1.645388e+07
# Korea, Rep.           3.649939e+07
# Kuwait                1.206496e+06
# Lebanon               2.781846e+06
# Malaysia              1.457406e+07
# Mongolia              1.734851e+06
# Myanmar               3.343229e+07
# Nepal                 1.655174e+07
# Oman                  1.438205e+06
# Pakistan              9.368339e+07
# Philippines           5.263663e+07
# Saudi Arabia          1.247837e+07
# Singapore             2.667817e+06
# ...

# %%
print(average_AsiaPop.sort_values(by=['col1'],na_position='first'))

# %% [markdown]
# Combining the graph in the first question with the average population data for Asia, it can be observed that China and India are the most populous in terms of the world.

# %%
#Third analysis
