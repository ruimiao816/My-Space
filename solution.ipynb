# %%
# !pip install py-openaq
# Out:
# Requirement already satisfied: py-openaq in /srv/conda/envs/notebook/lib/python3.7/site-packages (1.1.0)

# %%
import pandas as pd
import seaborn as sns
import openaq
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
airQualityCities=pd.read_csv('https://raw.githubusercontent.com/thousandoaks/BEMM458_OLD/master/data/airQualityCities.csv')

# %%
airQualityCities.sample(5)
# Out:
#                 date.local                                location parameter  \
# 31002  2021-09-29 10:45:00                       DTU, Delhi - CPCB       no2
# 29984  2021-09-29 14:15:00          Dwarka-Sector 8, Delhi - DPCC       pm10
# 14716  2021-10-02 14:00:00                       London Harlington       no2
# 26961  2021-09-29 22:15:00  Jawaharlal Nehru Stadium, Delhi - DPCC       no2
# 17089  2021-10-01 15:00:00                                Thurrock       so2
#
#        value                    unit country    city  \
# 31002   23.0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 29984   94.0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 14716   17.0  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 26961   20.4  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 17089    2.0  b'\xc2\xb5g/m\xc2\xb3'      GB  London
#
#                         date.utc  coordinates.latitude  coordinates.longitude
# 31002  2021-09-29 05:15:00+00:00             28.750050              77.111261
# 29984  2021-09-29 08:45:00+00:00             28.571027              77.071901
# 14716  2021-10-02 13:00:00+00:00             51.488790              -0.441614
# 26961  2021-09-29 16:45:00+00:00             28.580280              77.233829
# 17089  2021-10-01 14:00:00+00:00             51.477070               0.317969

# %%
airQualityCities.head()
# Out:
#             date.local                       location parameter  value  \
# 0  2021-10-12 23:00:00  US Diplomatic Post: New Delhi      pm25 -999.0
# 1  2021-10-12 18:00:00                Southend-on-Sea      pm10   14.0
# 2  2021-10-12 18:00:00                  London Eltham      pm25    8.0
# 3  2021-10-12 18:00:00         Tower Hamlets Roadside       no2   36.0
# 4  2021-10-12 18:00:00                  London Eltham       no2   15.0
#
#                      unit country    city                   date.utc  \
# 0  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi  2021-10-12 17:30:00+00:00
# 1  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 2  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 3  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 4  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
#
#    coordinates.latitude  coordinates.longitude
# 0             28.635760              77.224450
# 1             51.544206               0.678408
# 2             51.452580               0.070766
# 3             51.522530              -0.042155
# 4             51.452580               0.070766

# %%
airQualityCities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37087 entries, 0 to 37086
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date.local             37087 non-null  object
#  1   location               37087 non-null  object
#  2   parameter              37087 non-null  object
#  3   value                  37087 non-null  float64
#  4   unit                   37087 non-null  object
#  5   country                37087 non-null  object
#  6   city                   37087 non-null  object
#  7   date.utc               37087 non-null  object
#  8   coordinates.latitude   37087 non-null  float64
#  9   coordinates.longitude  37087 non-null  float64
# dtypes: float64(3), object(7)
# memory usage: 2.8+ MB

# %%
airQualityCities.groupby('city').count()
# Out:
#          date.local  location  parameter  value   unit  country  date.utc  \
# city
# Beijing         300       300        300    300    300      300       300
# Berlin         2248      2248       2248   2248   2248     2248      2248
# Delhi         16265     16265      16265  16265  16265    16265     16265
# London         5772      5772       5772   5772   5772     5772      5772
# Madrid         7400      7400       7400   7400   7400     7400      7400
# Paris          5102      5102       5102   5102   5102     5102      5102
#
#          coordinates.latitude  coordinates.longitude
# city
# Beijing                   300                    300
# Berlin                   2248                   2248
# Delhi                   16265                  16265
# London                   5772                   5772
# Madrid                   7400                   7400
# Paris                    5102                   5102

# %%
airQualityCities.groupby('parameter').count()
# Out:
#            date.local  location  value   unit  country   city  date.utc  \
# parameter
# co               3248      3248   3248   3248     3248   3248      3248
# no2             10417     10417  10417  10417    10417  10417     10417
# o3               7401      7401   7401   7401     7401   7401      7401
# pm10             7206      7206   7206   7206     7206   7206      7206
# pm25             5783      5783   5783   5783     5783   5783      5783
# so2              3032      3032   3032   3032     3032   3032      3032
#
#            coordinates.latitude  coordinates.longitude
# parameter
# co                         3248                   3248
# no2                       10417                  10417
# o3                         7401                   7401
# pm10                       7206                   7206
# pm25                       5783                   5783
# so2                        3032                   3032

# %% [markdown]
# Q1

# %%
airQualityCitiesO3=airQualityCities[airQualityCities['parameter']=='o3']

# %%
O3value=airQualityCities[airQualityCities['parameter']=='o3']

# %%
O3value
# Out:
#                 date.local                           location parameter  \
# 13     2021-10-12 18:00:00                  London Harlington        o3
# 14     2021-10-12 18:00:00                           Thurrock        o3
# 15     2021-10-12 18:00:00  London Haringey Priory Park South        o3
# 19     2021-10-12 18:00:00                    Southend-on-Sea        o3
# 20     2021-10-12 18:00:00                      London Eltham        o3
# ...                    ...                                ...       ...
# 37069  2021-09-28 20:15:00               Rohini, Delhi - DPCC        o3
# 37074  2021-09-28 20:15:00          NSIT Dwarka, Delhi - CPCB        o3
# 37076  2021-09-28 20:15:00           Lodhi Road, Delhi - IITM        o3
# 37080  2021-09-28 20:15:00     Dwarka-Sector 8, Delhi - DPCC         o3
# 37081  2021-09-28 20:15:00            Lodhi Road, Delhi - IMD        o3
#
#        value                    unit country    city  \
# 13     34.00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 14     25.00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 15     35.00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 19     34.00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# 20     24.00  b'\xc2\xb5g/m\xc2\xb3'      GB  London
# ...      ...                     ...     ...     ...
# 37069   6.10  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 37074  27.92  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 37076  17.16  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 37080   1.10  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 37081  19.71  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
#
#                         date.utc  coordinates.latitude  coordinates.longitude
# 13     2021-10-12 17:00:00+00:00             51.488790              -0.441614
# 14     2021-10-12 17:00:00+00:00             51.477070               0.317969
# 15     2021-10-12 17:00:00+00:00             51.584128              -0.125254
# 19     2021-10-12 17:00:00+00:00             51.544206               0.678408
# 20     2021-10-12 17:00:00+00:00             51.452580               0.070766
# ...                          ...                   ...                    ...
# 37069  2021-09-28 14:45:00+00:00             28.732528              77.119920
# 37074  2021-09-28 14:45:00+00:00             28.609090              77.032541
# 37076  2021-09-28 14:45:00+00:00             28.588333              77.221667
# 37080  2021-09-28 14:45:00+00:00             28.571027              77.071901
# 37081  2021-09-28 14:45:00+00:00             28.591825              77.227307
#
# [7401 rows x 10 columns]

# %%
O3largerthan120=O3value[O3value['value']>120]

# %%
O3largerthan120
# Out:
#                 date.local                             location parameter  \
# 26683  2021-09-29 22:45:00           Jahangirpuri, Delhi - DPCC        o3
# 27279  2021-09-29 21:15:00            Ashok Vihar, Delhi - DPCC        o3
# 28675  2021-09-29 17:45:00                    DTU, Delhi - CPCB        o3
# 28868  2021-09-29 17:15:00                    DTU, Delhi - CPCB        o3
# 29656  2021-09-29 15:15:00               Aya Nagar, Delhi - IMD        o3
# 29718  2021-09-29 14:45:00          Chandni Chowk, Delhi - IITM        o3
# 29733  2021-09-29 14:45:00               Aya Nagar, Delhi - IMD        o3
# 30080  2021-09-29 13:45:00  IHBAS, Dilshad Garden, Delhi - CPCB        o3
# 36164  2021-09-28 22:15:00            Ashok Vihar, Delhi - DPCC        o3
# 36327  2021-09-28 22:00:00        North Campus, DU, Delhi - IMD        o3
# 36504  2021-09-28 15:00:00                              ES1801A        o3
#
#         value                    unit country    city  \
# 26683  162.20  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 27279  125.70  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 28675  263.70  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 28868  147.20  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 29656  272.67  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 29718  295.15  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 29733  278.88  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 30080  148.23  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 36164  205.50  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 36327  121.33  b'\xc2\xb5g/m\xc2\xb3'      IN   Delhi
# 36504  124.00  b'\xc2\xb5g/m\xc2\xb3'      ES  Madrid
#
#                         date.utc  coordinates.latitude  coordinates.longitude
# 26683  2021-09-29 17:15:00+00:00             28.732820              77.170633
# 27279  2021-09-29 15:45:00+00:00             28.695381              77.181665
# 28675  2021-09-29 12:15:00+00:00             28.750050              77.111261
# 28868  2021-09-29 11:45:00+00:00             28.750050              77.111261
# 29656  2021-09-29 09:45:00+00:00             28.470691              77.109936
# 29718  2021-09-29 09:15:00+00:00             28.656756              77.227234
# 29733  2021-09-29 09:15:00+00:00             28.470691              77.109936
# 30080  2021-09-29 08:15:00+00:00             28.681174              77.302523
# 36164  2021-09-28 16:45:00+00:00             28.695381              77.181665
# 36327  2021-09-28 16:30:00+00:00             28.657381              77.158545
# 36504  2021-09-28 16:00:00+00:00             40.300830              -3.458890

# %%
O3largerthan120.groupby('city').count()
# Out:
#         date.local  location  parameter  value  unit  country  date.utc  \
# city
# Delhi           10        10         10     10    10       10        10
# Madrid           1         1          1      1     1        1         1
#
#         coordinates.latitude  coordinates.longitude
# city
# Delhi                     10                     10
# Madrid                     1                      1

# %% [markdown]
# #The cities with levels of O3 larger than 120 µg/m³ are Delhi and Madrid

# %% [markdown]
# Q2

# %%
COofCities=airQualityCities[airQualityCities['parameter']=='co']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=COofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("CO", fontsize=18)
ax.set_xlabel("city")
ax.set_title("CO of cities")
sns.despine(offset=10)
plt.show()

# %% [markdown]
# The boxplot shows Berlin has the lowest value of CO.

# %%
NO2ofCities=airQualityCities[airQualityCities['parameter']=='no2']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=NO2ofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("NO2", fontsize=18)
ax.set_xlabel("city")
ax.set_title("NO2 of cities")
sns.despine(offset=10)
plt.show()

# %% [markdown]
# The boxplot shows Berlin has the lowest value of NO2.

# %%
O3ofCities=airQualityCities[airQualityCities['parameter']=='o3']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=O3ofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("O3", fontsize=18)
ax.set_xlabel("city")
ax.set_title("O3 of cities")
sns.despine(offset=10)
plt.show()

# %% [markdown]
# The boxplot shows Delhi has the lowest value of O3.

# %%
PM10ofCities=airQualityCities[airQualityCities['parameter']=='pm10']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=PM10ofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("PM10", fontsize=18)
ax.set_xlabel("city")
ax.set_title("PM10 of cities")
sns.despine(offset=10)
plt.show()

# %%
PM25ofCities=airQualityCities[airQualityCities['parameter']=='pm25']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=PM25ofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("PM25", fontsize=18)
ax.set_xlabel("city")
ax.set_title("PM25 of cities")
sns.despine(offset=10)
plt.show()

# %%
SO2ofCities=airQualityCities[airQualityCities['parameter']=='so2']

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.boxplot(
    x='city',
    y='value',
    data=SO2ofCities,
    fliersize=0,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 850])
ax.set_ylabel("SO2", fontsize=18)
ax.set_xlabel("city")
ax.set_title("SO2 of cities")
sns.despine(offset=10)
plt.show()

# %% [markdown]
# PM25 is the only element tested in all cities and London has the lowest value. Considering London also performs well in NO2, O3, PM10 and SO2, so London has the cleanest air.

# %% [markdown]
# Q3

# %%
airQualityLondon=airQualityCities[airQualityCities['city']=='London']

# %%
airQualityLondon.groupby('location').mean().sort_values(by='value',ascending=False)
# Out:
#                                        value  coordinates.latitude  \
# location
# London Haringey Priory Park South  29.631161             51.584128
# Tower Hamlets Roadside             24.288514             51.522530
# Southend-on-Sea                    18.670849             51.544206
# London Harlington                  18.375527             51.488790
# Thurrock                           17.024240             51.477070
# London Eltham                      16.832881             51.452580
#
#                                    coordinates.longitude
# location
# London Haringey Priory Park South              -0.125254
# Tower Hamlets Roadside                         -0.042155
# Southend-on-Sea                                 0.678408
# London Harlington                              -0.441614
# Thurrock                                        0.317969
# London Eltham                                   0.070766

# %% [markdown]
# The "London Haringey Priory Park South" location is the most poluted in London.

# %% [markdown]
# Q4

# %%
airQualityLondon.groupby(['date.local','location'])['value'].mean()
# Out:
# date.local           location
# 2021-09-28 16:00:00  London Eltham                        19.25
#                      London Haringey Priory Park South    32.50
#                      Southend-on-Sea                      20.75
#                      Thurrock                             18.00
#                      Tower Hamlets Roadside                8.00
#                                                           ...
# 2021-10-12 18:00:00  London Haringey Priory Park South    29.00
#                      London Harlington                    19.50
#                      Southend-on-Sea                      18.00
#                      Thurrock                             18.50
#                      Tower Hamlets Roadside               36.00
# Name: value, Length: 1899, dtype: float64

# %%
AQLondontimeandlocation=pd.DataFrame(airQualityLondon.groupby(['date.local','location'])['value'].mean())

# %%
AQLondontimeandlocation
# Out:
#                                                        value
# date.local          location
# 2021-09-28 16:00:00 London Eltham                      19.25
#                     London Haringey Priory Park South  32.50
#                     Southend-on-Sea                    20.75
#                     Thurrock                           18.00
#                     Tower Hamlets Roadside              8.00
# ...                                                      ...
# 2021-10-12 18:00:00 London Haringey Priory Park South  29.00
#                     London Harlington                  19.50
#                     Southend-on-Sea                    18.00
#                     Thurrock                           18.50
#                     Tower Hamlets Roadside             36.00
#
# [1899 rows x 1 columns]

# %%
airQualityLondon.groupby(['date.local','location'])['value'].max()
# Out:
# date.local           location
# 2021-09-28 16:00:00  London Eltham                        58.0
#                      London Haringey Priory Park South    57.0
#                      Southend-on-Sea                      62.0
#                      Thurrock                             56.0
#                      Tower Hamlets Roadside                8.0
#                                                           ...
# 2021-10-12 18:00:00  London Haringey Priory Park South    35.0
#                      London Harlington                    34.0
#                      Southend-on-Sea                      34.0
#                      Thurrock                             25.0
#                      Tower Hamlets Roadside               36.0
# Name: value, Length: 1899, dtype: float64

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.lineplot(
    x='date.local',
    y='value',
    hue='location',
    data=AQLondontimeandlocation,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 90])
ax.set_ylabel("VALUE", fontsize=18)
ax.set_xlabel("DATE.LOCAL")
ax.set_title("Evolution of Air Polution accross Time in Locations in London")
sns.despine(offset=10)
plt.show()

# %% [markdown]
# Q5

# %%
PM10andPM25ofLondon=airQualityLondon[(airQualityLondon['parameter']=='pm10')|(airQualityLondon['parameter']=='pm25')]

# %%
PM10andPM25ofLondon
# Out:
#                 date.local           location parameter  value  \
# 1      2021-10-12 18:00:00    Southend-on-Sea      pm10   14.0
# 2      2021-10-12 18:00:00      London Eltham      pm25    8.0
# 5      2021-10-12 18:00:00  London Harlington      pm10   17.0
# 8      2021-10-12 18:00:00      London Eltham      pm10   13.0
# 9      2021-10-12 18:00:00  London Harlington      pm25   10.0
# ...                    ...                ...       ...    ...
# 36873  2021-09-28 16:00:00    Southend-on-Sea      pm25    4.0
# 36900  2021-09-28 16:00:00    Southend-on-Sea      pm10    9.0
# 36940  2021-09-28 16:00:00      London Eltham      pm25    3.0
# 36965  2021-09-28 16:00:00           Thurrock      pm10   11.0
# 36982  2021-09-28 16:00:00      London Eltham      pm10    7.0
#
#                          unit country    city                   date.utc  \
# 1      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 2      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 5      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 8      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# 9      b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-10-12 17:00:00+00:00
# ...                       ...     ...     ...                        ...
# 36873  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-09-28 15:00:00+00:00
# 36900  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-09-28 15:00:00+00:00
# 36940  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-09-28 15:00:00+00:00
# 36965  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-09-28 15:00:00+00:00
# 36982  b'\xc2\xb5g/m\xc2\xb3'      GB  London  2021-09-28 15:00:00+00:00
#
#        coordinates.latitude  coordinates.longitude
# 1                 51.544206               0.678408
# 2                 51.452580               0.070766
# 5                 51.488790              -0.441614
# 8                 51.452580               0.070766
# 9                 51.488790              -0.441614
# ...                     ...                    ...
# 36873             51.544206               0.678408
# 36900             51.544206               0.678408
# 36940             51.452580               0.070766
# 36965             51.477070               0.317969
# 36982             51.452580               0.070766
#
# [2037 rows x 10 columns]

# %%
x = sns.scatterplot(x='date.local', y='value', hue='parameter',data=PM10andPM25ofLondon)
ax.set_title('Scatterplot of PM10 and PM25');
ax.set_xlabel('Date.Local');
ax.set_ylabel('Value');

# %%
fig, ax = plt.subplots(1, figsize=(14,7))
ax = sns.scatterplot(
    x='date.local',
    y='value',
    hue='parameter',
    data=PM10andPM25ofLondon,
    palette='deep',
    ax=ax)
ax.set_ylim([0, 80])
ax.set_ylabel("VALUE", fontsize=18)
ax.set_xlabel("DATE.LOCAL")
ax.set_title("PM10andPM25ofLondon")
sns.despine(offset=10)
plt.show()
