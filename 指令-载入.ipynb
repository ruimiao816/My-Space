# %% [markdown]
# #载入library

# %% [markdown]
# -数学指令

# %%
import numpy as np
import math

# %% [markdown]
# -图表指令

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
