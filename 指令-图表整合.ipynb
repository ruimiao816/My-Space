# %% [markdown]
# #图表整合

# %% [markdown]
# -API

# %%
api = 数据库名.OpenAQ()

status, resp = api.cities()

# %% [markdown]
# 运行status指令后
# 出现200则表明载入正常

# %%
resp

# %%
图表名1=api.图表名1(df=True,limit=数值）

# %%
图表名2=api.图表名2(df=True,limit=数值）
print (图表名2.head())

# %%
图表名3=api.图表名3(df=True,limit=数值）

# %%
图表名4=api.图表名4(df=True,limit=数值）

# %% [markdown]
# -在已生成图表中筛选项

# %% [markdown]
# 精确筛选

# %%
筛选项 = api.measurements(筛选项所在列名='筛选项', limit=10000, df=True)

# %% [markdown]
# 模糊筛选

# %%
pd.set_option('display.max_rows', 100)
图表名[图表名['包含筛选项所在列的另一列']=='包含筛选项的另一项']
摘到筛选项的精确名称后
筛选项 = api.measurements((筛选项所在列名='筛选项实际名称',, limit=100, df=True)

# %% [markdown]
# -同源图表整合

# %%
图表名 = pd.concat([筛选项1,筛选项2,筛选项3,筛选项4,...], axis=0)

# %% [markdown]
# -非同源图表整合

# %%
图表名 = pd.merge(图表1, 图表2,how='left', on='两张图表中相同的项')#how是指把图表1放在左边还是右边

# %%
图表名 = pd.merge(图表1, 图表2,how='left', left_on='图表1中的列名称', right_on='图表2中的列名称')#这里图表1中的列和图表2中的列内容一样，但表头名称
